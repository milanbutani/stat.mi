# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
teams = pd.read_csv('tms.csv')
teams.head()
# Out:
#     Rk                    Team   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0  1.0        Milwaukee Bucks*  26.9  60.0  22.0  61  21  8.87 -0.82  8.04
# 1  2.0  Golden State Warriors*  28.4  57.0  25.0  56  26  6.46 -0.04  6.42
# 2  3.0        Toronto Raptors*  27.3  58.0  24.0  56  26  6.09 -0.60  5.49
# 3  4.0              Utah Jazz*  27.3  50.0  32.0  54  28  5.26  0.03  5.28
# 4  5.0        Houston Rockets*  29.2  53.0  29.0  53  29  4.77  0.19  4.96
#
#      ...      TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  FT/FGA.1  \
# 0    ...      12.0  20.8   0.197   0.503    11.5  80.3     0.162
# 1    ...      12.6  22.5   0.182   0.508    11.7  77.1     0.205
# 2    ...      12.4  21.9   0.198   0.509    13.1  77.1     0.190
# 3    ...      13.4  22.9   0.217   0.507    12.4  80.3     0.189
# 4    ...      12.0  22.8   0.221   0.525    13.4  74.4     0.210
#
#                      Arena  Attend.  Attend./G
# 0             Fiserv Forum   721692      17602
# ...

# %%
teams.columns
# Out:
# Index(['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
#        'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'eFG%', 'TOV%', 'ORB%',
#        'FT/FGA', 'eFG%.1', 'TOV%.1', 'DRB%', 'FT/FGA.1', 'Arena', 'Attend.',
#        'Attend./G'],
#       dtype='object')

# %%
df = teams[['Team', 'ORtg', 'DRtg', 'NRtg']]
df = df.append({'Team':'Bulls', 'ORtg':115.2, 'DRtg':101.8, 'NRtg':13.4}, ignore_index=True)

# %%
sns.set(rc={'figure.figsize':(10,10)});
sns.set_style("whitegrid", {'axes.grid' : False});
ax = sns.scatterplot(x='ORtg', y='DRtg', data=df, color='darkseagreen');
prop = fm.FontProperties(fname='Liberator-Light.ttf');
plt.xticks(fontproperties=prop, size=14);
plt.yticks(fontproperties=prop, size=14);
plt.xlabel('Off. Rating', fontproperties=prop, size=12);
plt.ylabel('Def. Rating', fontproperties=prop, size=12);
plt.axhline(y=np.mean(df['DRtg']),linewidth=2, color='rebeccapurple');
plt.axvline(x=np.mean(df['ORtg']),linewidth=2, color='rebeccapurple');
ax.set_title('Offensive Vs. Defensive Rating', fontproperties=prop, size=20);
plt.savefig('warriors.png')

# %%
np.mean(df['ORtg'])
# Out:
# 106.46688963210703

# %%
np.mean(df['DRtg'])
# Out:
# 106.43461538461537

# %%
teams[teams['Team'] == 'Golden State Warriors*']
# Out:
#        Rk                    Team   Age     W     L  PW  PL    MOV   SOS  \
# 1     2.0  Golden State Warriors*  28.4  57.0  25.0  56  26   6.46 -0.04
# 32    3.0  Golden State Warriors*  28.8  58.0  24.0  56  26   5.98 -0.19
# 61    1.0  Golden State Warriors*  28.2  67.0  15.0  67  15  11.63 -0.28
# 91    1.0  Golden State Warriors*  27.4  73.0   9.0  65  17  10.76 -0.38
# 121   1.0  Golden State Warriors*  26.6  67.0  15.0  65  17  10.10 -0.09
# 154   4.0  Golden State Warriors*  26.3  51.0  31.0  54  28   4.80  0.34
# 191  11.0  Golden State Warriors*  25.3  47.0  35.0  44  38   0.89  0.42
# 403  13.0  Golden State Warriors*  24.6  42.0  40.0  40  42  -0.34  0.34
#
#        SRS    ...      TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  FT/FGA.1  \
# 1     6.42    ...      12.6  22.5   0.182   0.508    11.7  77.1     0.205
# 32    5.79    ...      14.1  21.0   0.195   0.504    12.6  76.3     0.186
# 61   11.35    ...      13.2  22.8   0.204   0.486    13.5  74.9     0.198
# ...

# %%
teams.head()
# Out:
#     Rk                    Team   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0  1.0        Milwaukee Bucks*  26.9  60.0  22.0  61  21  8.87 -0.82  8.04
# 1  2.0  Golden State Warriors*  28.4  57.0  25.0  56  26  6.46 -0.04  6.42
# 2  3.0        Toronto Raptors*  27.3  58.0  24.0  56  26  6.09 -0.60  5.49
# 3  4.0              Utah Jazz*  27.3  50.0  32.0  54  28  5.26  0.03  5.28
# 4  5.0        Houston Rockets*  29.2  53.0  29.0  53  29  4.77  0.19  4.96
#
#      ...      TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  FT/FGA.1  \
# 0    ...      12.0  20.8   0.197   0.503    11.5  80.3     0.162
# 1    ...      12.6  22.5   0.182   0.508    11.7  77.1     0.205
# 2    ...      12.4  21.9   0.198   0.509    13.1  77.1     0.190
# 3    ...      13.4  22.9   0.217   0.507    12.4  80.3     0.189
# 4    ...      12.0  22.8   0.221   0.525    13.4  74.4     0.210
#
#                      Arena  Attend.  Attend./G
# 0             Fiserv Forum   721692      17602
# ...

# %%
sns.set(rc={'figure.figsize':(7.5,5)});
sns.set_style("whitegrid", {'axes.grid' : False});
sns.distplot(teams['Age'], color='darkgray');
plt.xticks(fontproperties=prop, size=14);
plt.yticks(fontproperties=prop, size=14);
plt.xlabel('Avg Team Age', fontproperties=prop, size=16);
plt.ylabel('Precent per age', fontproperties=prop, size=16);
plt.title('Distribution of Avg. Team Age', fontproperties=prop, size=20)
plt.scatter(np.mean(teams['Age']), 0, marker = '^', color='red', s=50);
plt.scatter(27.4, 0, marker = '.', color='darkblue', s=200);
plt.scatter(np.mean(teams['Age']), 0, marker = '^', color='red', s=50);
#plt.savefig("reb.png")
